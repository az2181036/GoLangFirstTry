# %%
import pandas as pd

data = pd.read_csv('./clusterings.csv')
data.head()
# Out:
#     X   Y  Clusterings
# 0  88  38            0
# 1  66  28            0
# 2  83  46            0
# 3  78  36            0
# 4  87  88            1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

current_palette = sns.color_palette("muted", n_colors=8)
color_list = sns.color_palette(current_palette).as_hex()
sns.scatterplot(x='X', y='Y', hue='Clusterings', data=data, palette=color_list)
plt.show()
