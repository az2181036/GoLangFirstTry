# %%
import pandas as pd

clusterings = pd.read_csv('../clusterings.csv')
centers = pd.read_csv('../centers.csv')
clusterings['X'] = pd.to_numeric(clusterings['X'], errors='coerce')
clusterings['Clusterings'] = clusterings['Clusterings'].astype(int)

centers.dtypes
# Out:
# X         float64
# Y         float64
# center    float64
# dtype: object

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
# cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
sns.scatterplot(data = clusterings, x="X", y="Y", hue="Clusterings",palette=cmap)
sns.scatterplot(x=centers['X'], y=centers['Y'])

r = 25 / 2
for row in centers.itertuples():
    a = row.X
    b = row.Y
    theta = np.arange(0, 2*np.pi, 0.01)
    x = a + r * np.cos(theta)
    y = b + r * np.sin(theta)
    plt.plot(x, y)
plt.show()
